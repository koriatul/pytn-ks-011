# %% [markdown]
# <a href="https://colab.research.google.com/github/koriatul/pytn-ks-011/blob/main/PYTN_Assgn_1_4_KS_011_Koriatul_Qibtiah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Assigment Python 1**
# NAMA : Koriatul Qibtiah
# NO : PYTN-KS011-015

# %%
#mengimpor dua modul analisis data
import numpy as np
import pandas as pd

# %%
#membaca data 
london_crime = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/london_crime_by_lsoa.csv')
london_crime
# Out:
#           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# ...

# %%
#melihat 5 baris teratas dari data
london_crime.head()
# Out:
#    lsoa_code     borough               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11
# 2               Other violence      0  2015      5
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6

# %%
#melihat 5 baris terbawah dari data
london_crime.tail()
# Out:
#           lsoa_code     borough               major_category  \
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 13490599  Criminal Damage To Dwelling      0  2015      2
# 13490600            Personal Property      1  2015      6
# 13490601       Burglary in a Dwelling      0  2011      2
# 13490602            Business Property      0  2011      5
# 13490603                 Wounding/GBH      0  2015      6

# %%
#melihat tipe data
london_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13490604 entries, 0 to 13490603
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   lsoa_code       object
#  1   borough         object
#  2   major_category  object
#  3   minor_category  object
#  4   value           int64
#  5   year            int64
#  6   month           int64
# dtypes: int64(3), object(4)
# memory usage: 720.5+ MB

# %%
# melihat baris, kolom pada dataset
london_crime.shape
# Out:
# (13490604, 7)

# %%
#melihat kolom dari data
london_crime.columns
# Out:
# Index(['lsoa_code', 'borough', 'major_category', 'minor_category', 'value',
#        'year', 'month'],
#       dtype='object')

# %%
#menambah kolom
london_crime['Total'] =london_crime.sum(axis=1)
# Out:
# <ipython-input-8-e46800c4f71f>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   london_crime['Total'] =london_crime.sum(axis=1)

# %%
london_crime.head()
# Out:
#    lsoa_code     borough               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month  Total
# 0  Burglary in Other Buildings      0  2016     11   2027
# 1               Other violence      0  2016     11   2027
# 2               Other violence      0  2015      5   2020
# 3  Burglary in Other Buildings      0  2016      3   2019
# 4            Personal Property      0  2008      6   2014

# %%
# melihat banyaknya objek null
london_crime.isnull().sum()
# Out:
# lsoa_code         0
# borough           0
# major_category    0
# minor_category    0
# value             0
# year              0
# month             0
# Total             0
# dtype: int64

# %%
#melihat daftar index pada dataset
london_crime.index.values
# Out:
# array([       0,        1,        2, ..., 13490601, 13490602, 13490603])

# %%
#melihat ringkasan singkat 
london_crime.describe()
# Out:
#               value          year         month         Total
# count  1.349060e+07  1.349060e+07  1.349060e+07  1.349060e+07
# mean   4.779444e-01  2.012000e+03  6.500000e+00  2.018978e+03
# std    1.771513e+00  2.581989e+00  3.452053e+00  4.660875e+00
# min    0.000000e+00  2.008000e+03  1.000000e+00  2.009000e+03
# 25%    0.000000e+00  2.010000e+03  3.750000e+00  2.016000e+03
# 50%    0.000000e+00  2.012000e+03  6.500000e+00  2.019000e+03
# 75%    1.000000e+00  2.014000e+03  9.250000e+00  2.022000e+03
# max    3.090000e+02  2.016000e+03  1.200000e+01  2.327000e+03

# %%
# melihat isi data kolom major_category
london_crime['major_category']
# Out:
# 0                              Burglary
# 1           Violence Against the Person
# 2           Violence Against the Person
# 3                              Burglary
# 4                               Robbery
#                        ...
# 13490599                Criminal Damage
# 13490600                        Robbery
# 13490601                       Burglary
# 13490602                        Robbery
# 13490603    Violence Against the Person
# Name: major_category, Length: 13490604, dtype: object

# %%
# melihat isi data kolom year
london_crime['year']
# Out:
# 0           2016
# 1           2016
# 2           2015
# 3           2016
# 4           2008
#             ...
# 13490599    2015
# 13490600    2015
# 13490601    2011
# 13490602    2011
# 13490603    2015
# Name: year, Length: 13490604, dtype: int64

# %%
# melihat data dari kolom major_category lebih dari tahun 2007
major = london_crime[(london_crime['year'] > 2007)].groupby(['major_category','year',])['value'].sum()
major
# Out:
# major_category               year
# Burglary                     2008     88092
#                              2009     90619
#                              2010     86826
#                              2011     93315
#                              2012     93392
#                                       ...
# Violence Against the Person  2012    150014
#                              2013    146181
#                              2014    185349
#                              2015    218740
#                              2016    232381
# Name: value, Length: 81, dtype: int64

# %%
# mengganti kolom borough menjadi area
london_crime.rename(columns={'borough':'area'}, inplace=True )

# %%
london_crime.head()
# Out:
#    lsoa_code        area               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month  Total
# 0  Burglary in Other Buildings      0  2016     11   2027
# 1               Other violence      0  2016     11   2027
# 2               Other violence      0  2015      5   2020
# 3  Burglary in Other Buildings      0  2016      3   2019
# 4            Personal Property      0  2008      6   2014

# %%
# melihat data berdasarkan label yaitu area Croydon
Croydon = london_crime.loc[london_crime['area'] == 'Croydon']
print(Croydon)
# Out:
#           lsoa_code     area               major_category  \
# 0         E01001116  Croydon                     Burglary
# 42        E01001029  Croydon                        Drugs
# 43        E01001193  Croydon           Theft and Handling
# 55        E01001171  Croydon  Violence Against the Person
# 83        E01000996  Croydon                        Drugs
# ...             ...      ...                          ...
# 13490513  E01001146  Croydon              Sexual Offences
# 13490516  E01001111  Croydon              Criminal Damage
# 13490577  E01001135  Croydon              Criminal Damage
# 13490595  E01001144  Croydon  Violence Against the Person
# 13490602  E01001134  Croydon                      Robbery
#
#                        minor_category  value  year  month  Total
# 0         Burglary in Other Buildings      0  2016     11   2027
# 42                Possession Of Drugs      0  2010     12   2022
# 43                        Other Theft      1  2014      5   2020
# ...

# %%
# melihat data berdasarkan kondisi yaitu kategori major roberry
condition = london_crime['major_category']=='Robbery'
print(condition)
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4            True
#             ...
# 13490599    False
# 13490600     True
# 13490601    False
# 13490602     True
# 13490603    False
# Name: major_category, Length: 13490604, dtype: bool

# %%
london_crime[condition]
# Out:
#           lsoa_code                  area major_category     minor_category  \
# 4         E01004563            Wandsworth        Robbery  Personal Property
# 7         E01002633              Hounslow        Robbery  Personal Property
# 12        E01003852  Richmond upon Thames        Robbery  Personal Property
# 50        E01001206                Ealing        Robbery  Personal Property
# 66        E01000808               Bromley        Robbery  Personal Property
# ...             ...                   ...            ...                ...
# 13490536  E01002432            Hillingdon        Robbery  Business Property
# 13490557  E01002497            Hillingdon        Robbery  Business Property
# 13490576  E01004270         Tower Hamlets        Robbery  Personal Property
# 13490600  E01002504            Hillingdon        Robbery  Personal Property
# 13490602  E01001134               Croydon        Robbery  Business Property
#
#           value  year  month  Total
# ...

# %%
#menghapus kolom lsoa_code
london_crime.drop(['lsoa_code'], axis=1, inplace=True)

# %%
london_crime.head()
# Out:
#          area               major_category               minor_category  \
# 0     Croydon                     Burglary  Burglary in Other Buildings
# 1   Greenwich  Violence Against the Person               Other violence
# 2     Bromley  Violence Against the Person               Other violence
# 3   Redbridge                     Burglary  Burglary in Other Buildings
# 4  Wandsworth                      Robbery            Personal Property
#
#    value  year  month  Total
# 0      0  2016     11   2027
# 1      0  2016     11   2027
# 2      0  2015      5   2020
# 3      0  2016      3   2019
# 4      0  2008      6   2014

# %%
#melihat kategori  dari data kolom major_category lebih dari tahun 2007
major = london_crime[(london_crime['year'] > 2007)].groupby(['major_category','year',])['value'].sum()
major
# Out:
# major_category               year
# Burglary                     2008     88092
#                              2009     90619
#                              2010     86826
#                              2011     93315
#                              2012     93392
#                                       ...
# Violence Against the Person  2012    150014
#                              2013    146181
#                              2014    185349
#                              2015    218740
#                              2016    232381
# Name: value, Length: 81, dtype: int64

# %%
Violence_Against_the_Person = major['Violence Against the Person']
Violence_Against_the_Person
# Out:
# year
# 2008    159844
# 2009    160777
# 2010    157894
# 2011    146901
# 2012    150014
# 2013    146181
# 2014    185349
# 2015    218740
# 2016    232381
# Name: value, dtype: int64

# %%
#ubah data jadi dataframe
df_v = Violence_Against_the_Person.to_frame()
df_v
# Out:
#        value
# year
# 2008  159844
# 2009  160777
# 2010  157894
# 2011  146901
# 2012  150014
# 2013  146181
# 2014  185349
# 2015  218740
# 2016  232381

# %%
#ubah nama value jadi Violence_Against_the_Person
df_v = df_v.rename(columns={'value': 'Violence Against the Person'})
df_v
# Out:
#       Violence Against the Person
# year
# 2008                       159844
# 2009                       160777
# 2010                       157894
# 2011                       146901
# 2012                       150014
# 2013                       146181
# 2014                       185349
# 2015                       218740
# 2016                       232381

# %% [markdown]
# **MATPLOTLIB**

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# magic funstion 
# %matplotlib inline

# %%
print('Matplotlib version: ',mpl.__version__)
# Out:
# Matplotlib version:  3.7.1

# %%
print(plt.style.available)
mpl.style.use(['ggplot'])
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# Line Plot

# %%
df_v.plot(kind='line', figsize=(8,6), color='blue', linewidth='5')
plt.title('Violence Against the Person Crimes in London 2008-2016')
plt.ylabel('Number of Crimes')
plt.xlabel('Years')
plt.show()

# %% [markdown]
# Keterangan : dari data tersebut dapat terlihat bahwa jumlah kejahatan meningkat mulai dari tahun 2013 hingga 2016,
# dengan total kejahatanya yaitu 232381, dan paling sedikit pada tahun 2013 yaitu sebesar 146181 kejahatan.

# %%
# melihat total (jumlah) kejahatan Violence Against the Person terkecil
df_v.min()
# Out:
# Violence Against the Person    146181
# dtype: int64

# %%
# melihat total(jumlah) kejahatan Violence Against the Person terbanyak
df_v.max()
# Out:
# Violence Against the Person    232381
# dtype: int64

# %%
# melihat tahun kejahatan Violence Against the Person paling awal
vmin = df_v.reset_index()
vmin['year'].min()
# Out:
# 2008

# %%
# melihat tahun kejahatan Violence Against the Person paling akhir
vmax = df_v.reset_index()
vmax['year'].max()
# Out:
# 2016

# %%
Burglary = major['Burglary']
Burglary
# Out:
# year
# 2008    88092
# 2009    90619
# 2010    86826
# 2011    93315
# 2012    93392
# 2013    87222
# 2014    76053
# 2015    70489
# 2016    68285
# Name: value, dtype: int64

# %%
#ubah jadi dataframe
df = Burglary.to_frame()
df
# Out:
#       value
# year
# 2008  88092
# 2009  90619
# 2010  86826
# 2011  93315
# 2012  93392
# 2013  87222
# 2014  76053
# 2015  70489
# 2016  68285

# %%
#ubah nama 
df = df.rename(columns={'value': 'Burglary'})
df
# Out:
#       Burglary
# year
# 2008     88092
# 2009     90619
# 2010     86826
# 2011     93315
# 2012     93392
# 2013     87222
# 2014     76053
# 2015     70489
# 2016     68285

# %%
# menggabungkan Violence Against the Person	dan Burglary
result = pd.concat([df_v, df], axis=1)
result
# Out:
#       Violence Against the Person  Burglary
# year
# 2008                       159844     88092
# 2009                       160777     90619
# 2010                       157894     86826
# 2011                       146901     93315
# 2012                       150014     93392
# 2013                       146181     87222
# 2014                       185349     76053
# 2015                       218740     70489
# 2016                       232381     68285

# %%
# line plot gabungan Violence Against the Person	dan Burglary
result.plot()
plt.xlabel('Year')
plt.ylabel('Number of crime')
plt.title('Violence Against the Person dan Burglary in London 2008-2016')
plt.show()

# %% [markdown]
# Keterangan : dari data kejahatan diatas dapat disimpulkan bahwa Violence Against the Person merupakan category kejahatan lebih tinggi disetiap tahunnya dibandingkan dengan Burglary

# %%
#melihat kembali data paling terbawah dengan mengambil 10 data.
london_crime.tail(10)
# Out:
#                 area               major_category  \
# 13490594   Greenwich              Criminal Damage
# 13490595     Croydon  Violence Against the Person
# 13490596     Bromley           Theft and Handling
# 13490597       Brent           Theft and Handling
# 13490598  Hillingdon           Theft and Handling
# 13490599       Brent              Criminal Damage
# 13490600  Hillingdon                      Robbery
# 13490601      Sutton                     Burglary
# 13490602     Croydon                      Robbery
# 13490603      Merton  Violence Against the Person
#
#                              minor_category  value  year  month  Total
# 13490594  Criminal Damage To Other Building      0  2008      2   2010
# 13490595                         Harassment      0  2012      1   2013
# 13490596                   Theft From Shops      0  2010      7   2017
# 13490597        Theft/Taking of Pedal Cycle      0  2014     10   2024
# ...

# %%
#melihat area Croydon
croydon = london_crime[(london_crime['area']=='Croydon')]
croydon
# Out:
#              area               major_category               minor_category  \
# 0         Croydon                     Burglary  Burglary in Other Buildings
# 42        Croydon                        Drugs          Possession Of Drugs
# 43        Croydon           Theft and Handling                  Other Theft
# 55        Croydon  Violence Against the Person             Offensive Weapon
# 83        Croydon                        Drugs             Drug Trafficking
# ...           ...                          ...                          ...
# 13490513  Croydon              Sexual Offences                 Other Sexual
# 13490516  Croydon              Criminal Damage  Criminal Damage To Dwelling
# 13490577  Croydon              Criminal Damage        Other Criminal Damage
# 13490595  Croydon  Violence Against the Person                   Harassment
# 13490602  Croydon                      Robbery            Business Property
#
#           value  year  month  Total
# ...

# %%
# melihat area bromley kategori kejahatan minor lebih dari tahun 2015
cry = croydon[(croydon['year'] > 2015)].groupby(['minor_category','year'])['value'].sum()
cry
# Out:
# minor_category                          year
# Assault with Injury                     2016    2451
# Burglary in Other Buildings             2016     884
# Burglary in a Dwelling                  2016    1854
# Business Property                       2016      79
# Common Assault                          2016    2878
# Counted per Victim                      2016       0
# Criminal Damage To Dwelling             2016     744
# Criminal Damage To Motor Vehicle        2016    1301
# Criminal Damage To Other Building       2016     337
# Drug Trafficking                        2016      96
# Going Equipped                          2016      21
# Handling Stolen Goods                   2016      44
# Harassment                              2016    3305
# Motor Vehicle Interference & Tampering  2016     382
# Murder                                  2016       9
# Offensive Weapon                        2016     228
# Other Criminal Damage                   2016     837
# ...

# %%
# lineplot minor_category area croydon
cry.plot(kind='line', figsize=(15,8), color='green', linewidth='2')
plt.xlabel('Year')
plt.ylabel('Number of crime')
plt.title('Minor Category Area Croydon of 2016')
plt.show()

# %% [markdown]
# Keterangan : dari line diatas minor category pada area croydon ditahun 2016 yaitu:
# 1. kasus kejahatan tertinggi yaitu Harassment sebanyak 3305 kasus
# 2. kemudian Other Theft sebanyak 3203 kasus
# 3. dan Common Assault sebanyak 2878
#
# dan kategori kasus terendah yang memiliki kasus sama sekali yaitu pada kategori:
# 1. Counted per Victim
# 2. Other Fraud & Forgery
# 3. Other Sexual, dan
# 4. Rape

# %% [markdown]
# **AREA PLOT**

# %%
# area plots scripting layer
# stacked  = menentukan bar/plot pada grafik di-stacked (ditumpuk) atau tidak
# alpha = mengatur tingkat transparansi

df_v.plot(kind='area',alpha=0.5,stacked=True,figsize=(10,5))
plt.title('Violence Against the Person in London 2008-2016')
plt.ylabel('Number of Crimes')
plt.xlabel('Years')
plt.show()

# %% [markdown]
# Keterangan : dari data tersebut dapat terlihat bahwa jumlah kejahatan meningkat mulai dari tahun 2013 hingga 2016, dengan total kejahatanya yaitu 232381, dan paling sedikit pada tahun 2013 yaitu sebesar 146181 kejahatan.

# %%
#melihat major category burglary lebih dari 2007
#brg = df[(df['year'] > 2007)].groupby(['major_category','year'])['value'].sum()
#brg

# %%
# area plot major category burglary 2016
df.plot(kind='area', figsize=(13,8))
plt.xlabel('Year')
plt.ylabel('Number of crime')
plt.title('Major Category Burglary of 2016', color='blue')
plt.show()

# %% [markdown]
# Keterangan bahwa dari major category yaitu kasus tentang burglary memiliki kasus kejahatan tertinggi pada tahun 2012 sebanyak 93392 dan kasus terendah pada tahun 2016 sebanyak 68285 kasus.

# %%
# area plot gabungan Violence Against the Person dan Burglary
result.plot(kind='area', figsize=(10,5))
plt.xlabel('Year')
plt.ylabel('Number of crime')
plt.title('Violence Against the Person With Burglary in London')
plt.show()

# %% [markdown]
# Keterangan : dari data kejahatan diatas dapat disimpulkan bahwa Violence Against the Person merupakan category kejahatan lebih tinggi disetiap tahunnya dibandingkan dengan Burglary

# %%
# area plot artist layer
ax = result.plot(kind='area',alpha=0.35,figsize=(10,5))
ax.set_title("Violence Against the Person With Burglary in London")
ax.set_ylabel('Number of Crimes')
ax.set_xlabel('Years')
plt.show()

# %% [markdown]
# Keterangan : dari data kejahatan diatas dapat disimpulkan bahwa Violence Against the Person merupakan category kejahatan lebih tinggi disetiap tahunnya dibandingkan dengan Burglary

# %% [markdown]
# **BAR CHART**

# %%
result.plot(kind='bar')
plt.title('Violence Against the Person With Burglary 2008-1016')
plt.ylabel('Number of Crimes')
plt.xlabel('Number of case')
plt.show()

# %% [markdown]
# Keterangan : sudah sangat jelas perbedaan dari 2 kategori kejahatan tersebut yaitu bahwa Violence Against the Person merupakan category kejahatan lebih tinggi disetiap tahunnya dibandingkan dengan Burglary

# %%
df_v.plot(kind='bar', color='orange')
plt.title('Violence Against the Person 2008-2016')
plt.ylabel('Number of Crimes')
plt.xlabel('Number of case')
plt.show()

# %% [markdown]
# Keterangan : pada bar chart diatas bahwa kejahatan memiliki kenaikan kasus di tahun 2013 hingga 2016.kasus terendah berada ditahun 2013 dan tertinggi ditahun 2016.

# %%
# merubah bar vertikal menjadi horizontal
df_v.plot(kind='barh')
plt.title('Violence Against the Person 2008-1016')
plt.ylabel('Number of Crimes')
plt.xlabel('Number of case')
plt.show()

# %% [markdown]
# Keterangan : pada bar chart diatas bahwa kejahatan memiliki kenaikan kasus di tahun 2013 hingga 2016.kasus terendah berada ditahun 2013 dan tertinggi ditahun 2016.

# %%
# melihat data dari kolom minor_category kurang dari tahun 2008
minor = london_crime[(london_crime['year'] > 2008)].groupby(['minor_category','year',])['value'].sum()
minor
# Out:
# minor_category       year
# Assault with Injury  2009    55297
#                      2010    54173
#                      2011    50768
#                      2012    50369
#                      2013    39929
#                              ...
# Wounding/GBH         2012     7151
#                      2013    15526
#                      2014    21556
#                      2015    23431
#                      2016    23525
# Name: value, Length: 256, dtype: int64

# %%
ass  = minor['Assault with Injury']
ass
# Out:
# year
# 2009    55297
# 2010    54173
# 2011    50768
# 2012    50369
# 2013    39929
# 2014    45677
# 2015    48164
# 2016    50038
# Name: value, dtype: int64

# %%
#buat data frame
df_a = ass.to_frame()
df_a
# Out:
#       value
# year
# 2009  55297
# 2010  54173
# 2011  50768
# 2012  50369
# 2013  39929
# 2014  45677
# 2015  48164
# 2016  50038

# %%
#rename kolom
df_a = df_a.rename(columns={'value': 'Assault with Injury'})
df_a
# Out:
#       Assault with Injury
# year
# 2009                55297
# 2010                54173
# 2011                50768
# 2012                50369
# 2013                39929
# 2014                45677
# 2015                48164
# 2016                50038

# %%
df_a.plot(kind='bar',figsize=(10,7))
plt.title('Assault With Injury 2009-2016')
plt.ylabel('number of cases')
plt.xlabel('year')

plt.annotate('',xy=(7,52000), xytext=(4,40000), arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='blue', lw=4))

plt.annotate('Mengalami Peningkatan', xy=(4.5,50000))
plt.show()

# %% [markdown]
# pada bar chart diatas minor category AssaultwithInjury mengalami peningkatan pada tahun 2013 hingga 2016

# %%
#Analisa Wilayah berdasarkan jumlah kasus di tahun 2012

area = (london_crime[(london_crime['year'] == 2012)].groupby('area')['value'].sum()).sort_values(ascending=False)
area
# Out:
# area
# Westminster               59226
# Lambeth                   33473
# Camden                    31472
# Southwark                 30737
# Croydon                   30189
# Newham                    30067
# Ealing                    28832
# Hackney                   27095
# Tower Hamlets             26784
# Brent                     26357
# Islington                 26268
# Wandsworth                24457
# Lewisham                  23652
# Barnet                    23573
# Haringey                  23231
# Hounslow                  22724
# Waltham Forest            22647
# Hillingdon                22103
# Redbridge                 21424
# Enfield                   21069
# Hammersmith and Fulham    21030
# Greenwich                 20028
# Kensington and Chelsea    19757
# Bromley                   19622
# Barking and Dagenham      15990
# Havering                  15965
# Merton                    12856
# Harrow                    12803
# Bexley                    11669
# ...

# %%
# 5 Wilayah teratas dari jumlah kasus terbanyak di tahun 2012

top5 = (area.head(5)).sort_values()
top5.plot(kind='bar', figsize=(5, 5), color='red')
plt.xlabel('area')
plt.ylabel('Number of Crime')
plt.title('Top 5 area with the most crimes in 2012')
plt.show()

# %% [markdown]
# pada data tersebut ada 5 wilayah yang memiliki kasus kejahatan tertinggi yaitu croydon, southwark, camden, lambeth, dan westminster , tetapi wilayah yang memiliki kasus kejahatan tertinggi yaitu Westminster.

# %% [markdown]
# PIE CHART

# %%
# pie chart menggambarkan proporsi dari data
top5.plot(kind='pie',figsize=(5,6),autopct='%1.1f%%', startangle=90, shadow=True)
plt.title('Top 5 area with the most crimes in 2012')
plt.axis('equal')
plt.show()

# %%
colors_list = ['purple','yellowgreen','brown','azure','lightskyblue']
top5.plot(kind='pie',figsize=(5,6),autopct='%1.1f%%', startangle=90, shadow=True, colors=colors_list)
plt.title('Top 5 area with The Most Crimes In 2012')
plt.axis('equal')
plt.show()

# %% [markdown]
# dari 5 wilayah diatas yang memiliki tingkat kejahatan tertinggi yaitu wilayah Westminster sebanyak 32.0% dan kasus kejahatan terkecil yaitu wilayah Croydon.

# %%
# menampilkan data di ara Westminster
wmt =london_crime[london_crime['area']=='Westminster']
wmt
# Out:
#                  area               major_category  \
# 21        Westminster           Theft and Handling
# 46        Westminster              Criminal Damage
# 74        Westminster  Violence Against the Person
# 134       Westminster           Theft and Handling
# 165       Westminster           Theft and Handling
# ...               ...                          ...
# 13490302  Westminster  Violence Against the Person
# 13490346  Westminster           Theft and Handling
# 13490386  Westminster                      Robbery
# 13490545  Westminster           Theft and Handling
# 13490565  Westminster           Theft and Handling
#
#                                   minor_category  value  year  month  Total
# 21                         Handling Stolen Goods      0  2012      2   2014
# 46                         Other Criminal Damage      0  2008     11   2019
# 74                                  Wounding/GBH      0  2009      9   2018
# ...

# %%
# mengetahui jumlah kejahatan di Westminster berdasarkan major_category
west = wmt[(wmt['year'] > 2012 )].groupby(['major_category'])[['value']].agg('sum')
west
# Out:
#                               value
# major_category
# Burglary                      13711
# Criminal Damage                8357
# Drugs                         11106
# Fraud or Forgery                  0
# Other Notifiable Offences      2996
# Robbery                        7450
# Sexual Offences                   0
# Theft and Handling           117512
# Violence Against the Person   36009

# %%
# memilih warna untuk masing-masing kategori kejahatan
colors_list = ['lightcoral', 'gray', 'green',
               'lavender','yellowgreen', 'lightskyblue',
               'olive', 'yellow','lavender']

# mengatur tampilan pie
explode_list = [0, 0, 0, 0, 0, 0, 0, 0, 0]

west['value'].plot(kind='pie',
               figsize=(5, 5),
               startangle=90,
               colors=colors_list,
               pctdistance=1.5,
               explode=explode_list)

plt.title('Major Criminal Case in Westminster 2016', y=1.12)
plt.show()

# %% [markdown]
# pie chart diatas dapat disimpulkan bahwa Thef and Handling merupakan kategori kejahatan terbanyak ditahun 2016

# %% [markdown]
# **Histogram**

# %%
result
# Out:
#       Violence Against the Person  Burglary
# year
# 2008                       159844     88092
# 2009                       160777     90619
# 2010                       157894     86826
# 2011                       146901     93315
# 2012                       150014     93392
# 2013                       146181     87222
# 2014                       185349     76053
# 2015                       218740     70489
# 2016                       232381     68285

# %%
# membuat histogram kategori Violence Against the Person dan Burglary
result.plot(kind='hist')
plt.title("Histogram Of Violence Against the Person dan Burglary 2008-2016")
plt.ylabel('number of years')
plt.xlabel('number of crimes')
plt.show()

# %% [markdown]
# pada histogram diatas kategori Violence Against the Person dan Burglary , dapat dilihat bahwa Violence Against the Person lebih tinggi disetiap tahunnya.

# %%
# membuat dataframe dengan index berupa year dan kolom berupa jenis kejahatan yang terjadi berdasarkan major category
table = london_crime.pivot_table(values='value',
                        index=['year'],
                        columns=['major_category'],
                        aggfunc=np.sum,
                        fill_value=0)
table
# Out:
# major_category  Burglary  Criminal Damage  Drugs  Fraud or Forgery  \
# year
# 2008               88092            91872  68804              5325
# 2009               90619            85565  60549                 0
# 2010               86826            77897  58674                 0
# 2011               93315            70914  57550                 0
# 2012               93392            62158  51776                 0
# 2013               87222            56206  50278                 0
# 2014               76053            59279  44435                 0
# 2015               70489            62976  39785                 0
# 2016               68285            64071  38914                 0
#
# major_category  Other Notifiable Offences  Robbery  Sexual Offences  \
# year
# 2008                                10112    29627             1273
# 2009                                10644    29568                0
# 2010                                10768    32341                0
# ...

# %%
# membuat histogram jenis kejahatan yang terjadi di london pada tahun 2008-2016 berdasarkan major category
count, bin_edges = np.histogram(table, 15)
table.plot(kind='hist',
           figsize=(18, 7),
           bins=15,
           alpha=0.6,
           stacked=True,
           xticks=bin_edges
           )

plt.title('Histogram of major criminal in 2008-2016')
plt.ylabel('Number of Years')
plt.xlabel('Number of Criminal ')

plt.show()

# %% [markdown]
# Berdasarkan histogram major criminal diatas , dengan jenis kejahatan Burglary, Criminal Damage, Drugs, Fraud or Forgery, Other Notifiable Offences, Robbery, Sexual Offences, Thef and Handling dan Violence Against The Person , Thef and Handling yang memiliki kasus kejahatan tertinggi sebanyak 334054 kasus.

# %%
# membuat dataframe dengan index berupa year dan kolom berupa jenis kejahatan yang terjadi berdasarkan minor category
table_a = london_crime.pivot_table(values='value',
                        index=['year'],
                        columns=['minor_category'],
                        aggfunc=np.sum,
                        fill_value=0)
table_a
# Out:
# minor_category  Assault with Injury  Burglary in Other Buildings  \
# year
# 2008                          56586                        31437
# 2009                          55297                        30434
# 2010                          54173                        29703
# 2011                          50768                        30876
# 2012                          50369                        31676
# 2013                          39929                        30685
# 2014                          45677                        27078
# 2015                          48164                        25833
# 2016                          50038                        25289
#
# minor_category  Burglary in a Dwelling  Business Property  Common Assault  \
# year
# 2008                             56655               2964           37356
# 2009                             60185               3115           39671
# 2010                             57123               3041           41591
# ...

# %%
# membuat histogram jenis kejahatan yang terjadi di london tahun 2008-2016 berdasarkan minor category
count, bin_edges = np.histogram(table, 15)
table_a.plot(kind='hist',figsize=(18, 7),
           bins=15,
           alpha=0.6,
           stacked=True,
           xticks=bin_edges
           )

plt.title('Histogram of minor criminal in 2008-2016')
plt.ylabel('Number of Years')
plt.xlabel('Number of Criminal ')

plt.show()

# %% [markdown]
# Berdasarkan histogram minor criminal diatas  yang terjadi di London dari tahun 2008-2016 yaitu Assault with Injury, Burglary in Other, Buildings, Burglary in a Dwelling, Business Property, Common Assault, Counted per Victim, Criminal Damage To Dwelling, Criminal Damage To Motor Vehicle, Criminal Damage To Other Building, Drug Trafficking, Going Equipped, Handling Stolen Goods,Harassment, Motor Vehicle Interference & Tampering, Murder,Offensive Weapon, Other Criminal Damage, Other Drugs, Other Fraud & Forgery, Other Notifiable, Other Sexual, Other Theft, Other Theft Person, Other violence,Personal Property, Possession Of Drugs, Rape, Theft From Motor Vehicle, Theft From Shops, Theft/Taking Of Motor Vehicle, Theft/Taking of Pedal Cycle, Wounding/GBH. yang memiliki kasaus kejahatan terbanyak sepanjang 2008-2016 adalah Other Theft dengan jumlah 132056 selama 8 tahun terakhir.

# %% [markdown]
# **Box Plot**

# %%
df.describe()
# Out:
#            Burglary
# count      9.000000
# mean   83810.333333
# std     9658.166674
# min    68285.000000
# 25%    76053.000000
# 50%    87222.000000
# 75%    90619.000000
# max    93392.000000

# %%
df.plot(kind='box', figsize=(10,7))
plt.title('Box Plot Of Major Category Burglary From 2008-2016')
plt.ylabel('Number of crime')
plt.show()

# %% [markdown]
# Keterangan :
# Box plot diatas menunjukan kategori kejahatan Burglary memiliki rata-rata 	83810.333333 , minimum kasus yaitu 68285.000000 dan maximum kasus yaitu 93392.000000

# %%
result.describe()
# Out:
#        Violence Against the Person      Burglary
# count                     9.000000      9.000000
# mean                 173120.111111  83810.333333
# std                   32113.207526   9658.166674
# min                  146181.000000  68285.000000
# 25%                  150014.000000  76053.000000
# 50%                  159844.000000  87222.000000
# 75%                  185349.000000  90619.000000
# max                  232381.000000  93392.000000

# %%
result.plot(kind='box',figsize=(8,7), vert=False, color='green')
plt.title('Box Plot Of Major Category Violence Against the Person	and Burglary')
plt.ylabel('Number of crime')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Keterangan : Box plot diatas menunjukan kategori kejahatan Burglary memiliki rata-rata 83810.333333 lebih rendah dibandingan dengan Violence Against the Person yang memiliki rata rata yaitu 173120.111111 .

# %% [markdown]
# **Scatter Plot**

# %%
major
# Out:
# major_category               year
# Burglary                     2008     88092
#                              2009     90619
#                              2010     86826
#                              2011     93315
#                              2012     93392
#                                       ...
# Violence Against the Person  2012    150014
#                              2013    146181
#                              2014    185349
#                              2015    218740
#                              2016    232381
# Name: value, Length: 81, dtype: int64

# %%
df_v = df_v.rename(columns={'Violence Against the Person': 'total'})
df_v
# Out:
#    year   total
# 0  2008  159844
# 1  2009  160777
# 2  2010  157894
# 3  2011  146901
# 4  2012  150014
# 5  2013  146181
# 6  2014  185349
# 7  2015  218740
# 8  2016  232381

# %%
df_v.plot(kind='scatter', x='year', y='total', figsize=(10,6),color='green')
plt.title('Violence Against the Person Crimes From 2008-2016')
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.show()

# %% [markdown]
# Pada Scater Plot diatas dapat disumpulkan bahwa kategori vioelence against the person mengalami kenaikan lebih pesat mulai tahun 2013 s/d 2016.

# %%
result
# Out:
#       Violence Against the Person  Burglary
# year
# 2008                       159844     88092
# 2009                       160777     90619
# 2010                       157894     86826
# 2011                       146901     93315
# 2012                       150014     93392
# 2013                       146181     87222
# 2014                       185349     76053
# 2015                       218740     70489
# 2016                       232381     68285

# %%
result.reset_index(inplace=True)
result
# Out:
#    year  Violence Against the Person  Burglary
# 0  2008                       159844     88092
# 1  2009                       160777     90619
# 2  2010                       157894     86826
# 3  2011                       146901     93315
# 4  2012                       150014     93392
# 5  2013                       146181     87222
# 6  2014                       185349     76053
# 7  2015                       218740     70489
# 8  2016                       232381     68285

# %%
w = (result['Burglary']-result['Burglary'].min()) / (result['Burglary'].max() - result['Burglary'].min())

a = (result['Violence Against the Person']-result['Violence Against the Person'].min()) / (result['Violence Against the Person'].max() - result['Violence Against the Person'].min())

# %%
x0 =  result.plot(kind='scatter', x='year', y='Burglary', figsize=(10, 8), alpha=0.5, color="red", s=w* 1000 +10, xlim=(2008,2016))

x1 =  result.plot(kind='scatter', x='year', y='Violence Against the Person', alpha=0.5, color="blue", s=a * 1000 +10, ax = x0)

x0.set_ylabel('Number of Crimes')
x0.set_title('Crimes Category Violence Against the Person and Burglary from 2008-2016')
x0.legend(['Burglary','Violence Against the Person'], 
loc='upper left', fontsize='x-large')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# Pada scater plot diatas dapat disimpulkan bahwa Burglary dan Violence Against the Person memiliki tingkat kejahatan yang berbeda-beda disetiap tahunnya. tetapi kejahatan tertinggi yaitu Violence Against the Person dibanding dengan Burglary.

# %% [markdown]
# Summary:
# Berdasarkan data kejahatan (london_crime_by_lsoa) pada tahun 2008-2016 terdapat 33 wilayah , yang terdiri dari kejahatan utama dan kejahatan kecil, kategori utama(major) ada 9 jenis kategori , kemudian kejahatan kecil yaitu ada 32 , dapat saya simpulkan:
#
# 1. 5 wilayah dengan kejahatan tertinggi pada tahun 2016 adalah Tower Hamlets 29253 kasus, Newham 30090 kasus, Southwark 31636 kasus, Lambeth 34071 kasus, dan Westminster 48330 kasus.
# 2. Kota dengan tindak kejahatan tertinggi selama 2008-2016 adalah Westminster, sedangkan kota dengan tindak kejahatan terendah selama 2008-2016 adalah City of London sebesar 178 kasus.
# 3. Jenis kejahatan utama terbanyak yaitu Theft and Handling dengan jumlah 334054 kasus sepanjang 2008-2016.
# 4. Jenis kejahatan kecil terbanyak banyak yaitu Other Theft dengan jumlah 132056 selama 8 tahun terakhir (2008-2016).

# %% [markdown]
# **WordClouds**

# %%
# import wordclouds library
from wordcloud import WordCloud, STOPWORDS

# %%
# kata yang ada pada kolom area
stopwords = list(london_crime['area'])
stopwords
# Out:
# ['Croydon',
#  'Greenwich',
#  'Bromley',
#  'Redbridge',
#  'Wandsworth',
#  'Ealing',
#  'Ealing',
#  'Hounslow',
#  'Newham',
#  'Sutton',
#  'Haringey',
#  'Lambeth',
#  'Richmond upon Thames',
#  'Wandsworth',
#  'Hillingdon',
#  'Havering',
#  'Barking and Dagenham',
#  'Redbridge',
#  'Kingston upon Thames',
#  'Sutton',
#  'Redbridge',
#  'Westminster',
#  'Hackney',
#  'Enfield',
#  'Ealing',
#  'Hackney',
#  'Harrow',
#  'Ealing',
#  'Haringey',
#  'Lewisham',
#  'Ealing',
#  'Hounslow',
#  'Bromley',
#  'Havering',
#  'Hillingdon',
#  'Brent',
#  'Haringey',
#  'Hounslow',
#  'Lambeth',
#  'Southwark',
#  'Havering',
#  'Newham',
#  'Croydon',
#  'Croydon',
#  'Barnet',
#  'Waltham Forest',
#  'Westminster',
#  'Lambeth',
#  'Lewisham',
#  'Bromley',
#  'Ealing',
#  'Brent',
#  'Haringey',
#  'Camden',
#  'Bexley',
#  'Croydon',
#  'Lewisham',
#  'Hounslow',
#  'Camden',
#  'Kensington and Chelsea',
#  'Hounslow',
#  'Lewisham',
#  'Kingston upon Thames',
#  'Brent',
# ...

# %%
text = ' '.join(london_crime['area'].astype(str).tolist())

# %%
london_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13490604 entries, 0 to 13490603
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   area            object
#  1   major_category  object
#  2   minor_category  object
#  3   value           int64
#  4   year            int64
#  5   month           int64
#  6   Total           int64
# dtypes: int64(4), object(3)
# memory usage: 720.5+ MB

# %%
lc = WordCloud(width=800, height=800, background_color='white', 
               min_font_size=10).generate(text)

# %%
# nama wilayah yang paling sering muncul
fig = plt.figure(figsize=(10,10))
plt.imshow(lc ,interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# dapat disimpulkan bahwa nama wilayah yang paling sering muncul adalah Waltham Forest, Tower Hamlets, Upon Thames, Richmon Upon, dan Kingston Upon

# %%
from PIL import Image
alice_mask = np.array(Image.open('/content/drive/MyDrive/Colab Notebooks/alice_mask.png'))

# %%
alice_mask
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
fig = plt.figure()
fig.set_figwidth(7)
fig.set_figheight(7)
plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
plt.imshow(alice_mask,cmap=plt.cm.gray)
plt.axis('off')
plt.show()

# %%
stopwords = set(STOPWORDS)

# %%
lc = WordCloud(background_color='white',max_words=2000,mask=alice_mask,stopwords=stopwords)
lc.generate(text)
plt.figure(figsize=(10,10))
plt.imshow(lc)
plt.axis('off')
plt.show()

# %%
#mencoba pergantian background black
lc = WordCloud(background_color='black',max_words=2000,mask=alice_mask,stopwords=stopwords)
lc.generate(text)
plt.figure(figsize=(10,10))
plt.imshow(lc)
plt.axis('off')
plt.show()

# %% [markdown]
# **Folium Maps**

# %%
# !pip install folium
import folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#London Lat and Lon
latitude= 51.5085300 #garis lintang
longitude= -0.1257400 #garis bujur

# %%
# Zoom in di London
london_map = folium.Map(location=[ 51.5085300 ,-0.1257400],zoom_start=11)
london_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Ganti Tipe Peta
london_map_stamen = folium.Map(location=[51.5085300 ,-0.1257400],zoom_start=11,tiles='Stamen Toner')
london_map_stamen
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#menampilkan area
area
# Out:
# area
# Westminster               59226
# Lambeth                   33473
# Camden                    31472
# Southwark                 30737
# Croydon                   30189
# Newham                    30067
# Ealing                    28832
# Hackney                   27095
# Tower Hamlets             26784
# Brent                     26357
# Islington                 26268
# Wandsworth                24457
# Lewisham                  23652
# Barnet                    23573
# Haringey                  23231
# Hounslow                  22724
# Waltham Forest            22647
# Hillingdon                22103
# Redbridge                 21424
# Enfield                   21069
# Hammersmith and Fulham    21030
# Greenwich                 20028
# Kensington and Chelsea    19757
# Bromley                   19622
# Barking and Dagenham      15990
# Havering                  15965
# Merton                    12856
# Harrow                    12803
# Bexley                    11669
# ...

# %%
# menampilkan area Tower Hamlets
tower = folium.Map(location=[51.5202607,-0.0293396],zoom_start=11,tiles='Stamen Terrain')
tower
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# menampilkan area top5
kota = {
    'area': ['Tower Hamlets', 'Newham', 'Southwark', 'Lambeth', 'Westminster'],
    'latitude': [ 51.520261, 51.525516 , 51.502781, 51.457148, 39.8366528],
    'longitude': [-0.029340, 0.035216, -0.087738, -0.123068, -105.0372046]
}

df_kota = pd.DataFrame(kota)
df_kota
# Out:
#             area   latitude   longitude
# 0  Tower Hamlets  51.520261   -0.029340
# 1         Newham  51.525516    0.035216
# 2      Southwark  51.502781   -0.087738
# 3        Lambeth  51.457148   -0.123068
# 4    Westminster  39.836653 -105.037205

# %%
top5area = folium.map.FeatureGroup()

for lat, lng, in zip(df_kota.latitude, df_kota.longitude):
    top5area.add_child(
        folium.CircleMarker(
           location= [lat, lng],
           radius=5,
           color='red',
           fill=True,
           fill_color='blue',
           fill_opacity=0.6
        )  
    )
london_map.add_child(top5area)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
london
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-186-86eca1fc13ee> in <module>
# ----> 1 london
#
# NameError: name 'london' is not defined
