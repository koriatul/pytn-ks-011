# %% [markdown]
# <a href="https://colab.research.google.com/github/koriatul/pytn-ks-011/blob/main/Sesi_9___Descriptive_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DESCRIPTIVE STATISTICS**

# %%
from PIL import Image
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/1.png')
img.show()
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/2.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=612x453 at 0x7F192D1CB940>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=374x170 at 0x7F192D1CB7C0>

# %% [markdown]
# [0,4,8] Umur
#
# Mean = 4
#
# n = 3
#
# Stdev = (( 16 + 0 + 16 )/3-1)^1/2 =(32/2)^1/2 = 4 tahun
#
# Variance = 16 tahun kuadrat
#
# Q2 = Median = Percentile 50

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/3.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1265x536 at 0x7F192D1CBE80>

# %%
import math
import statistics
import numpy as np
import scipy.stats
import pandas as pd

# %%
math.nan
# Out:
# nan

# %%
np.nan
# Out:
# nan

# %%
x = [8,1,2.5,4,28]
x_with_nan = [8,1,2.5,np.nan, 4,28]
print(x)
print(x_with_nan)
# Out:
# [8, 1, 2.5, 4, 28]
# [8, 1, 2.5, nan, 4, 28]

# %%
#buat array(y) dan Series(z) dari x
y , y_with_nan = np.array(x), np.array(x_with_nan) #array
z , z_with_nan = pd.Series(x), pd.Series(x_with_nan)

print(y)
print(y_with_nan)
print(z)
print(z_with_nan)
# Out:
# [ 8.   1.   2.5  4.  28. ]
# [ 8.   1.   2.5  nan  4.  28. ]
# 0     8.0
# 1     1.0
# 2     2.5
# 3     4.0
# 4    28.0
# dtype: float64
# 0     8.0
# 1     1.0
# 2     2.5
# 3     NaN
# 4     4.0
# 5    28.0
# dtype: float64

# %%
z_with_nan.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %% [markdown]
# **Central Tendency**

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/4.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=157x143 at 0x7F18F60F2790>

# %% [markdown]
# Arithmetic Mean

# %% [markdown]
# 1. x itu list
# 2. y itu array
# 3. z itu Series

# %%
x
# Out:
# [8, 1, 2.5, 4, 28]

# %%
sum(x)
# Out:
# 43.5

# %%
len(x)
# Out:
# 5

# %%
mean_x = sum(x)/len(x)
mean_x
# Out:
# 8.7

# %%
mean_stats = statistics.mean(x)
print(mean_stats)
# Out:
# 8.7

# %%
mean_np = np.mean(x)
print(mean_np)
# Out:
# 8.7

# %%
y
# Out:
# array([ 8. ,  1. ,  2.5,  4. , 28. ])

# %%
y.mean() #array
# Out:
# 8.7

# %%
z.mean() #series
# Out:
# 8.7

# %%
y_with_nan.mean()
# Out:
# nan

# %%
np.mean(y_with_nan)
# Out:
# nan

# %%
np.nan*3
# Out:
# nan

# %%
np.nanmean(y_with_nan) #get mean without considering NaN values
# Out:
# 8.7

# %%
z_with_nan.mean() #Series langsung merata2kan tanpa mempertimbangkan NaN values
# Out:
# 8.7

# %%
z_with_nan
# Out:
# 0     8.0
# 1     1.0
# 2     2.5
# 3     NaN
# 4     4.0
# 5    28.0
# dtype: float64

# %% [markdown]
# Weighted Mean

# %% [markdown]
# Rata-rata dengan menghitung pembobotan

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/5.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=251x201 at 0x7F18F60F2B80>

# %%
x = [8,1,2.5,4,28] #Metrics
w = [0.1,0.2,0.3,0.25,0.15] #Weightages

#convert jadi array
y,z,w = np.array(x),pd.Series(x),np.array(w)

wmean = np.average(y , weights=w)
print(wmean)
# Out:
# 6.95

# %%
#manual calculation
wmean_manual = sum(w[i]*x[i] for i in range(len(x)))/sum(w)
print(wmean)
# Out:
# 6.95

# %%
sum(w)
# Out:
# 1.0

# %% [markdown]
# Harmonic Mean

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/6.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=400x137 at 0x7F18F60F2DF0>

# %% [markdown]
# Sering dipakai untuk Rata-rata Rate (10km/jam,100kg/hari,1000000 orang/tahun)

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/7.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=626x31 at 0x7F18F60B15E0>

# %%
speed = [60,20]
hmean_speed = len(speed)/sum(1/item for item in speed)
hmean_speed
# Out:
# 30.0

# %%
# hmean dengan library 1
hmean_speed_stats = statistics.harmonic_mean(speed)
hmean_speed_stats
# Out:
# 30.0

# %%
# hmean dengan library 1
hmean_speed_stats2 = scipy.stats.hmean(speed)
hmean_speed_stats2
# Out:
# 30.0

# %%
x
# Out:
# [8, 1, 2.5, 4, 28]

# %%
hmean = len(x) / sum(1/item for item in x)
hmean
# Out:
# 2.7613412228796843

# %%
arit_mean = np.mean(x)
arit_mean
# Out:
# 8.7

# %%
x
# Out:
# [8, 1, 2.5, 4, 28]

# %%
for item in x:
    print(1/item)
# Out:
# 0.125
# 1.0
# 0.4
# 0.25
# 0.03571428571428571

# %%
list(1/item for item in x)
# Out:
# [0.125, 1.0, 0.4, 0.25, 0.03571428571428571]

# %%
# hmean dgn library
hmean_stats = statistics.harmonic_mean(x)
hmean_stats
# Out:
# 2.7613412228796843

# %% [markdown]
# Geometric Mean

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/8.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1280x720 at 0x7F18F60C25E0>

# %% [markdown]
# Perusahaan berdiri pada tahun 2017
#
# tahun 2017 omsetnya 1000
#
# di tahun 2018 naik 30 %
#
# di tahun 2019 naik 50 %
#
# di tahun 2020 naik 40 %

# %%
x = 1000
x*=1.3 #1300
x*=1.5 #1950
x*=1.4 #2730
x
# Out:
# 2730.0

# %%
# Arithmetic Mean
(30+50+40)/3
# Out:
# 40.0

# %%
x = 1000
x*=1.4
x*=1.4
x*=1.4
x
# Out:
# 2743.9999999999995

# %%
#Geometric Mean
gmean = ((30*50*40)**(1/3))
gmean
# Out:
# 39.148676411688626

# %%
x = 1000
x*=1.3915
x*=1.3915
x*=1.3915
x
# Out:
# 2694.322835875

# %%
scipy.stats.gmean([30,50,40]) #geometric mean menggunakan library scipy
# Out:
# 39.14867641168864

# %% [markdown]
# **Median**

# %%
#Ganjil
a = [1,2,4,8,9]
n = len(a)
median = a[2]
median
# Out:
# 4

# %%
#Genap
a = [1,2,4,8]
n = len(a)
(n+1)/2
median = (2+4)/2
median
# Out:
# 3.0

# %%
# Menggunakan numpy
x = [8, 1, 2.5, 4, 28]
c = [2,3,4,5]
np.median(c)
# Out:
# 3.5

# %%
# Pembuktian manual
def median_function(x):
    n = len(x)
    if n%2 == 1: #Ganjil
        median_ = sorted(x)[round(0.5*(n-1))] #ambil median
    else: #Genap
        x_ord, index = sorted(x) , round(0.5*n)
        median_=0.5 * (x_ord[index-1]+x_ord[index])

# %%
median_function(x)

# %%
median_function(c)

# %%
sorted(x)
# Out:
# [1, 2.5, 4, 8, 28]

# %%
n = len([1,2,3,4,5,6,7])
round(0.5*(n-1))
# Out:
# 3

# %%
n
# Out:
# 7

# %% [markdown]
# Mode / Modus

# %% [markdown]
# Nilai yang paling sering banyak muncul/frekuensi paling tinggi

# %%
u = [2,3,2,8,12]

mode_ = max((u.count(i),i)for i in set(u))[1]

# %%
statistics.mode(u)
# Out:
# 2

# %%
scipy.stats.mode(u)[0][0]
# Out:
# <ipython-input-59-d8f8f9254a13>:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   scipy.stats.mode(u)[0][0]
# 2

# %%
mode_lib = scipy.stats.mode(u)
# Out:
# <ipython-input-60-11d63c7822d9>:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_lib = scipy.stats.mode(u)

# %%
print(mode_lib)
print(mode_lib.mode)
print(mode_lib.count)
# Out:
# ModeResult(mode=array([2]), count=array([2]))
# [2]
# [2]

# %%
u
# Out:
# [2, 3, 2, 8, 12]

# %%
u_series = pd.Series(u)
u_series.mode()
# Out:
# 0    2
# dtype: int64

# %%
u_array = np.array(u)
statistics.mode(u_array)
# Out:
# 2

# %%
v = pd.Series([1,2,3,3,3,np.nan,np.nan,np.nan,np.nan])
v.mode()
# Out:
# 0    3.0
# dtype: float64

# %%
statistics.mode(v)
# Out:
# 3.0

# %%
h = [1,2,3,3,3,np.nan,np.nan,np.nan,np.nan]
statistics.mode(h)
# Out:
# nan

# %% [markdown]
# Series akan mengabaikan NaN dan List akan mempertimbangkan NaN

# %% [markdown]
# **Measures of Variability**

# %% [markdown]
# Variance

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/9.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=767x189 at 0x7F191D328C40>

# %%
x
# Out:
# [8, 1, 2.5, 4, 28]

# %%
n  = len(x)
mean_var = np.mean(x)
var_ = sum((item-mean_var)**2 for item in x ) / (n-1)
var_
# Out:
# 123.19999999999999

# %%
# Variance w/ statistics library
var_stat = statistics.variance(x)
var_stat
# Out:
# 123.2

# %%
# variance w/ numpy
var_np = np.var(x,ddof=1)
var_np
# Out:
# 123.19999999999999

# %%
# Variance using Series function
z = pd.Series(x)
z.var()
# Out:
# 123.19999999999999

# %% [markdown]
# Standard Deviasi

# %% [markdown]
#  Quiz hitung variance dan standar deviasi

# %%
x = [1,2,3,6,7,8,30,40,50]
std_dev = statistics.stdev(x)
print("Standar Deviasi dari x adalah:", std_dev)

variance = statistics.variance(x)
print("Variansi dari x adalah:", variance)
# Out:
# Standar Deviasi dari x adalah: 18.58090417606205
# Variansi dari x adalah: 345.25000000000006

# %%
#Kuis 1 tim 4
x = [1,2,3,6,7,8,30,40,50]
n = len(x)
mean = sum(x)/n
var_ = sum((item - mean)**2 for item in x)/(n-1)
Sd_ = var_**(1/2) #

print(var_)
print(Sd_)
# Out:
# 345.25000000000006
# 18.58090417606205

# %%
x = [8, 1, 2.5, 4, 28]

# %%
var_np
# Out:
# 123.19999999999999

# %%
stdev = var_np**(1/2)
stdev
# Out:
# 11.099549540409285

# %%
stdev = np.sqrt(var_np) 
stdev
# Out:
# 11.099549540409285

# %%
# stdev with statistics library
stdev = statistics.stdev(x)
stdev
# Out:
# 11.099549540409287

# %%
stdev = np.std(x,ddof=1)
stdev
# Out:
# 11.099549540409285

# %% [markdown]
# **SKewness**

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/3.png')
img.show()
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/10.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1265x536 at 0x7F191D335B50>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=480x45 at 0x7F191D335F10>

# %%
x
# Out:
# [8, 1, 2.5, 4, 28]

# %%
n = len(x)
mean = np.mean(x)
stdev = statistics.stdev(x)
skew_ = (sum((item - mean)**3 for item in x))*n / ((n-1)*(n-2)*(stdev**3))
skew_
# Out:
# 1.947043227390592

# %%
scipy.stats.skew(x,bias=False)
# Out:
# 1.9470432273905927

# %%
z = pd.Series(x)
z.skew()
# Out:
# 1.9470432273905924

# %%
scipy.stats.skew(x_with_nan)
# Out:
# nan

# %%
z_with_nan = pd.Series(x_with_nan)
z_with_nan.skew()
# Out:
# 1.9470432273905924

# %%
scipy.stats.skew(z_with_nan)
# Out:
# nan

# %% [markdown]
# **Percentiles**

# %%
x = [-5,-1.1,0.1,2,8,12.8,21,25.8,41]
np.percentile(x,5) #Percentile 5
# Out:
# -3.44

# %%
np.percentile(x,0)
# Out:
# -5.0

# %%
np.percentile(x,100)
# Out:
# 41.0

# %%
np.percentile(x,90)
# Out:
# 28.840000000000003

# %%
statistics.quantiles(x,n=2)
# Out:
# [8.0]

# %%
statistics.quantiles(x,n=4)
# Out:
# [-0.5, 8.0, 23.4]

# %%
statistics.quantiles(x,n=4,method='inclusive')
# Out:
# [0.1, 8.0, 21.0]

# %%
x
# Out:
# [-5, -1.1, 0.1, 2, 8, 12.8, 21, 25.8, 41]

# %%
np.quantile(x,0)
# Out:
# -5.0

# %%
np.quantile(x,1)
# Out:
# 41.0

# %%
np.quantile(x,0.5)
# Out:
# 8.0

# %%
x
# Out:
# [-5, -1.1, 0.1, 2, 8, 12.8, 21, 25.8, 41]

# %%
x_with_nan = [-5, -1.1,np.nan, 0.1, 2, 8, 12.8, 21, 25.8, 41]
x_with_nan
# Out:
# [-5, -1.1, nan, 0.1, 2, 8, 12.8, 21, 25.8, 41]

# %%
np.quantile(x_with_nan,0)
# Out:
# nan

# %%
np.nanquantile(x_with_nan,0.5)
# Out:
# 8.0

# %%
x
# Out:
# [-5, -1.1, 0.1, 2, 8, 12.8, 21, 25.8, 41]

# %%
np.quantile(x,[0.25,0.5,0.75])
# Out:
# array([ 0.1,  8. , 21. ])

# %%
statistics.quantiles(x,n=4,method='inclusive')
# Out:
# [0.1, 8.0, 21.0]

# %%
np.percentile(x,[25,50,75])
# Out:
# array([ 0.1,  8. , 21. ])

# %% [markdown]
# **Ranges (nilai Max - nilai Min)**

# %%
x # Ranges  = 41 - (-5) = 46
# Out:
# [-5, -1.1, 0.1, 2, 8, 12.8, 21, 25.8, 41]

# %%
# np.ptp untuk menghitung range
np.ptp(x)
# Out:
# 46.0

# %%
np.amax(x)
# Out:
# 41.0

# %%
np.amin(x)
# Out:
# -5.0

# %%
np.amax(x) - np.amin(x)
# Out:
# 46.0

# %% [markdown]
# Interquartile Range (Q3-Q1) (biasanya digunakan untuk mendeteksi outlier)

# %%
from PIL import Image
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/11.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x178 at 0x7F191D33DB80>

# %%
x
# Out:
# [-5, -1.1, 0.1, 2, 8, 12.8, 21, 25.8, 41]

# %%
quartiles = np.quantile(x,[0.25,0.75])
IQR = quartiles[1] - quartiles[0]
IQR
# Out:
# 20.9

# %% [markdown]
# Summary of Desc. Stats

# %%
x
# Out:
# [-5, -1.1, 0.1, 2, 8, 12.8, 21, 25.8, 41]

# %%
result = scipy.stats.describe(x,ddof=1,bias=False)
result
# Out:
# DescribeResult(nobs=9, minmax=(-5.0, 41.0), mean=11.622222222222222, variance=228.75194444444446, skewness=0.9249043136685094, kurtosis=0.14770623629658886)

# %%
(result.variance)**(1/2)
# Out:
# 15.12454774346805

# %%
result.minmax[1]-result.minmax[0]
# Out:
# 46.0

# %%
result.skewness
# Out:
# 0.9249043136685094

# %%
z = pd.Series(x)
z
# Out:
# 0    -5.0
# 1    -1.1
# 2     0.1
# 3     2.0
# 4     8.0
# 5    12.8
# 6    21.0
# 7    25.8
# 8    41.0
# dtype: float64

# %%
z.describe()
# Out:
# count     9.000000
# mean     11.622222
# std      15.124548
# min      -5.000000
# 25%       0.100000
# 50%       8.000000
# 75%      21.000000
# max      41.000000
# dtype: float64

# %% [markdown]
# **Correlation**

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/12.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=701x335 at 0x7F18F6098DF0>

# %%
x = list(range(-10,11))
y = [0 , 2, 2, 2, 2, 3, 3, 6, 7, 4, 7, 6, 6, 9, 4, 5, 5, 10, 11, 12, 14]
x_ar, y_ar = np.array(x),np.array(y)
x_s,y_s = pd.Series(x),pd.Series(y)

# %%
len(x)==len(y)
# Out:
# True

# %% [markdown]
# **Covariance**

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/13.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=679x153 at 0x7F18F5738520>

# %%
n = len(x)
mean_x = np.mean(x)
mean_y = np.mean(y)

cov_xy = (sum((x[item]-mean_x)*(y[item]-mean_y) for item in range(n)))/(n-1)
cov_xy
# Out:
# 19.95

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/15.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=607x291 at 0x7F18F60B19D0>

# %%
cov_matrix = np.cov(x,y)
cov_matrix
# Out:
# array([[38.5       , 19.95      ],
#        [19.95      , 13.91428571]])

# %%
np.var(x,ddof=1)
# Out:
# 38.5

# %%
np.var(y,ddof=1)
# Out:
# 13.914285714285711

# %%
cov_xy = cov_matrix[0,1]
cov_xy
# Out:
# 19.95

# %%
cov_xy = cov_matrix[1,0]
cov_xy
# Out:
# 19.95

# %% [markdown]
# **Correlation Coefficient**

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/16.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=320x134 at 0x7F18F5738760>

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi 9_descriptive statistic/17.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=915x436 at 0x7F18F60C7910>

# %% [markdown]
# r = 1 / r= -1 atau mendekati merupakan tanda kedua variabel mengalami multicollinearity

# %%
var_x = np.var(x,ddof=1)
var_y = np.var(y,ddof=1)
cov_xy
std_x = np.std(x,ddof=1)
std_y = np.std(y,ddof=1)
r = cov_xy / (std_x*std_y)
r
# Out:
# 0.861950005631606

# %% [markdown]
# Korelasi positif sangat kuat karena sangat mendekati 1

# %%
xy_corr = scipy.stats.pearsonr(x,y).statistic
xy_corr
# Out:
# 0.8619500056316061

# %%
p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-149-6c10289a8da7> in <module>
# ----> 1 p
#
# NameError: name 'p' is not defined

# %%
corr_matrix = np.corrcoef(x,y)
corr_matrix
# Out:
# array([[1.        , 0.86195001],
#        [0.86195001, 1.        ]])

# %%
scipy.stats.linregress(x,y).rvalue
# Out:
# 0.861950005631606

# %% [markdown]
# Pada 2D Array

# %%
a = np.array([[1,1,1],
             [2,3,1],
             [4,9,2],
             [8,27,4],
             [16,1,1]])

# %%
np.mean(a)
# Out:
# 5.4

# %%
np.median(a)
# Out:
# 2.0

# %%
np.mean(a,axis=0)
# Out:
# array([6.2, 8.2, 1.8])

# %%
np.mean(a,axis=0)
# Out:
# array([6.2, 8.2, 1.8])

# %%
np.var(a,ddof=1)
# Out:
# 53.40000000000001

# %%
np.var(a,ddof=1,axis=0)
# Out:
# array([ 37.2, 121.2,   1.7])

# %% [markdown]
# Pada DataFrame

# %%
row_names = ['first','second','third','fourth','fifth']
col_names=['A','B','C']
df = pd.DataFrame(a,index=row_names,columns=col_names)
df
# Out:
#          A   B  C
# first    1   1  1
# second   2   3  1
# third    4   9  2
# fourth   8  27  4
# fifth   16   1  1

# %%
np.mean(df.A)
# Out:
# 6.2

# %%
df['A'].mean()
# Out:
# 6.2

# %%
np.var(df,ddof=1)
# Out:
# A     37.2
# B    121.2
# C      1.7
# dtype: float64

# %%
df.var()
# Out:
# A     37.2
# B    121.2
# C      1.7
# dtype: float64

# %%
df
# Out:
#          A   B  C
# first    1   1  1
# second   2   3  1
# third    4   9  2
# fourth   8  27  4
# fifth   16   1  1

# %%
df.mean(axis=0)
# Out:
# A    6.2
# B    8.2
# C    1.8
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# first      1.0
# second     2.0
# third      5.0
# fourth    13.0
# fifth      6.0
# dtype: float64
