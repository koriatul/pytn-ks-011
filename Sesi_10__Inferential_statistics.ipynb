# %% [markdown]
# <a href="https://colab.research.google.com/github/koriatul/pytn-ks-011/blob/main/Sesi_10__Inferential_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Inferential Statistics

# %%
from PIL import Image
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/1.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=480x360 at 0x7FD6BFF3A640>

# %%
import matplotlib.pyplot as plt
from IPython.display import Math, Latex
from IPython.core.display import Image

# %%
import seaborn as sns #Visualisasi data
sns.set(color_codes=True)

# %% [markdown]
# **Uniform Distribution**

# %%
from PIL import Image
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/2.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=266x190 at 0x7FD69E33E670>

# %%
from scipy.stats import uniform

# %%
data_uniform = uniform.rvs(size=10000,loc=10,scale=10)

# %%
sns.distplot(data_uniform)
plt.xlabel('Uniform Distribution')
plt.show()
# Out:
# <ipython-input-11-708cb7fdc151>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_uniform)

# %% [markdown]
# **Normal Distribution**

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/3.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=782x581 at 0x7FD69E33E550>

# %% [markdown]
# μ = Rata-Rata
#
# σ = Standar Deviasi

# %%
from scipy.stats import norm

data_normal = norm.rvs(size=10000,loc=0,scale=1)

sns.distplot(data_normal)
# Out:
# <ipython-input-13-fad841e227a1>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_normal)
# <Axes: ylabel='Density'>

# %% [markdown]
# Gamma Distribution (Continuous)

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/4.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=576x384 at 0x7FD682A4B370>

# %%
len(gamma.rvs(size=10000,a=5))
# Out:
# 10000

# %%
from scipy.stats import gamma
data_gamma = gamma.rvs(size=10000,a=100)
sns.distplot(data_gamma)
# Out:
# <ipython-input-18-bbe9dfe227e1>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_gamma)
# <Axes: ylabel='Density'>

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/5.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=492x388 at 0x7FD682A4B280>

# %%
from scipy.stats import expon
data_expon = expon.rvs(scale=1,loc=0,size=1000)
sns.distplot(data_expon)
# Out:
# <ipython-input-21-fed278625475>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_expon)
# <Axes: ylabel='Density'>

# %% [markdown]
# **Poisson Distribution (Discrete/Count Data)**

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/6.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1370x992 at 0x7FD682823430>

# %%
from scipy.stats import poisson
data_poisson = poisson.rvs(mu=3,size=10000)
sns.distplot(data_poisson)
plt.xlabel('Poisson Distribution (Count Data)')
# Out:
# <ipython-input-23-e0195ac4ebc3>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_poisson)
# Text(0.5, 0, 'Poisson Distribution (Count Data)')

# %% [markdown]
# **Binomial Distribution (Discrete)**

# %%
from scipy.stats import binom
data_binom = binom.rvs(n=10,p=0.8,size=10000)
sns.distplot(data_binom)
# Out:
# <ipython-input-24-8c28f43edc96>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_binom)
# <Axes: ylabel='Density'>

# %% [markdown]
# **Bernoulli Distribution (Discrete)**

# %%
from scipy.stats import bernoulli
data_bern = bernoulli.rvs(size=10000,p=0.6)
sns.distplot(data_bern)
# Out:
# <ipython-input-25-8e00688a8486>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_bern)
# <Axes: ylabel='Density'>

# %% [markdown]
# **Confidence Interval**

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/7.png')
img.show()
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/8.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=658x97 at 0x7FD682602FD0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=570x52 at 0x7FD6826023D0>

# %% [markdown]
# Contoh 160 +- 5
#
# Batas Bawah 155
#
# Batas Atas 165
#
# Confidence Interval 95% Maka Z-Score 1.96

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/9.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=196x282 at 0x7FD6828837C0>

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/10.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=718x338 at 0x7FD6826E9E50>

# %% [markdown]
# **Confidence Interval for the Population Proportion**

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# Sex 1 itu Pria dan 0 itu wanita
#
# Target 1 itu Sakit Jantung , 0 itu bukan Penderita Sakit Jantung

# %%
def sex_label(x):
    if x==1:
        return 'Male'
    else:
        return 'Female'

# %%
df['sex_label'] = df['sex'].apply(sex_label)
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target sex_label
# 0   2     3       0      Male
# 1   0     3       0      Male
# 2   0     3       0      Male
# 3   1     3       0      Male
# 4   3     2       0    Female

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        1025 non-null   int64
#  1   sex        1025 non-null   int64
#  2   cp         1025 non-null   int64
#  3   trestbps   1025 non-null   int64
#  4   chol       1025 non-null   int64
#  5   fbs        1025 non-null   int64
#  6   restecg    1025 non-null   int64
#  7   thalach    1025 non-null   int64
#  8   exang      1025 non-null   int64
#  9   oldpeak    1025 non-null   float64
#  10  slope      1025 non-null   int64
#  11  ca         1025 non-null   int64
#  12  thal       1025 non-null   int64
#  13  target     1025 non-null   int64
#  14  sex_label  1025 non-null   object
# dtypes: float64(1), int64(13), object(1)
# memory usage: 120.2+ KB

# %%
df.isna().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps     0
# chol         0
# fbs          0
# restecg      0
# thalach      0
# exang        0
# oldpeak      0
# slope        0
# ca           0
# thal         0
# target       0
# sex_label    0
# dtype: int64

# %%
df.target.value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/11.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=783x133 at 0x7FD6826BE640>

# %%
df.groupby(['sex_label','target'])[['target']].count()
# Out:
#                   target
# sex_label target
# Female    0           86
#           1          226
# Male      0          413
#           1          300

# %%
n = 86+226
pro_fm = 226/n
print(n,pro_fm)
# Out:
# 312 0.7243589743589743

# %%
stderror_fm = (pro_fm*(1-pro_fm)/n)**(1/2)
stderror_fm
# Out:
# 0.02529714756803247

# %% [markdown]
# Ambil confidence interval 95% (Z-Score = 1.96)

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/8.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=570x52 at 0x7FD6826020D0>

# %%
z_score = 1.96
low_ci_fm = pro_fm - (z_score*stderror_fm)
up_ci_fm = pro_fm + (z_score*stderror_fm)
print(low_ci_fm,up_ci_fm)
# Out:
# 0.6747765651256307 0.773941383592318

# %%
 print('Margin Error=',(z_score*stderror_fm))
# Out:
# Margin Error= 0.049582409233343644

# %% [markdown]
# Contoh Lain

# %%
import scipy.stats as stats
import random
import warnings

# %% [markdown]
# Generate Massa Populasi dalam Pounds dibagi menjadi wanita dan pria

# %%
normal_distribution_male = norm.rvs(loc=181,scale=24,size=6000)
normal_distribution_fem = norm.rvs(loc=132,scale=22,size=6500)
all_mass = np.concatenate([normal_distribution_male,normal_distribution_fem],axis=0)
df_mass = pd.DataFrame(all_mass,columns=['people_mass'])
df_mass
# Out:
#        people_mass
# 0       184.410594
# 1       156.939148
# 2       152.629466
# 3       199.689147
# 4       156.321711
# ...            ...
# 12495   133.461422
# 12496   117.852637
# 12497   115.959167
# 12498   148.700368
# 12499   133.148284
#
# [12500 rows x 1 columns]

# %%
len(normal_distribution_male)
# Out:
# 6000

# %%
len(normal_distribution_fem)
# Out:
# 6500

# %%
len(all_mass)
# Out:
# 12500

# %%
warnings.filterwarnings('ignore')

# %%
sns.distplot(df_mass['people_mass'])
plt.ylabel('Probability of Occurence')
plt.xlabel('Mass (Pounds)')
plt.show()

# %%
#Mean
population_mean = df_mass['people_mass'].mean()
population_mean
# Out:
# 155.39765523841837

# %%
# Standard Deviation
population_std = df_mass['people_mass'].std(ddof=1)
population_std
# Out:
# 33.304616269544766

# %% [markdown]
# Kita mengambil 250 sampel masing-masing sebanyak 30 orang per sampel

# %%
n = 30
sample_means=[]
for sample in range(0,250):
    sample_values= df_mass['people_mass'].sample(n)
    sample_mean = sample_values.mean()
    sample_means.append(sample_mean)

# %%
sns.distplot(sample_means)
# Out:
# <Axes: ylabel='Density'>

# %%
df_mass['people_mass'].sample(10)
# Out:
# 610      186.113564
# 11399     97.164403
# 1785     164.113914
# 11125    142.394891
# 11397    108.828374
# 7923     122.187465
# 9773     112.973106
# 3049     158.869389
# 1305     174.183270
# 7987     116.148211
# Name: people_mass, dtype: float64

# %% [markdown]
# ringkasan perhitungan

# %%
mean_of_sample_means = np.mean(sample_means)
median_of_sample_means = np.median(sample_means)
mean_of_sample_means , median_of_sample_means
# Out:
# (155.3335231961357, 155.34116864947848)

# %%
population_mean
# Out:
# 155.39765523841837

# %%
std_of_sample_means = np.std(sample_means)
std_of_sample_means
# Out:
# 6.1748539818542385

# %% [markdown]
# **Standard Error**

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/12.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1115x210 at 0x7FD6822C4640>

# %%
standard_error = population_std/np.sqrt(n)
standard_error
# Out:
# 6.080563199961075

# %%
std_of_sample_means
# Out:
# 6.1748539818542385

# %% [markdown]
# Kesimpulan Sample memiliki karakteristik yang serupa dengan Populasi

# %% [markdown]
# **Visualisasikan Area dari Confidence Interval**

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/13.png')
img.show()
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/8.png')
img.show()
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/14.png')
img.show()
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/9.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1800x1000 at 0x7FD6826028E0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=570x52 at 0x7FD682602D60>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=308x164 at 0x7FD6826020D0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=196x282 at 0x7FD682602D60>

# %%
stats.norm.cdf(2.17)
# Out:
# 0.9849965770262678

# %%
z = 1.96

# %%
lower_bound = mean_of_sample_means - z * standard_error
lower_bound
# Out:
# 143.415619324212

# %%
upper_bound = mean_of_sample_means + z * standard_error
upper_bound
# Out:
# 167.2514270680594

# %%
kde = stats.gaussian_kde(sample_means)
pos = np.linspace(np.min(sample_means),np.max(sample_means),10000)
plt.plot(pos,kde(pos))
shade = np.linspace(lower_bound,upper_bound,300)
plt.fill_between(shade,kde(shade),alpha=0.5)
plt.xlabel('Sample Mass (Pounds)')
plt.ylabel('Frequency')
plt.axvline(x=mean_of_sample_means,color='red')
plt.text(x=152,y=.01,s='Shaded area are \npart of the \nconfidence intervals \n95%')
# Out:
# Text(152, 0.01, 'Shaded area are \npart of the \nconfidence intervals \n95%')

# %% [markdown]
# **Hypothesis Testing**

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/15.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1500x1000 at 0x7FD682731A00>

# %% [markdown]
# alpha biasanya sama dengan 0.05 karena confidence level 95%
#
# Apabila confidence level 99% maka alpha 0.01

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/heart.csv')
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %% [markdown]
# Hypothesis Testing in Population Means

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nhanes_2015_2016.csv')
df
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0     83732     1.0     NaN     1.0       1         1        62         3
# 1     83733     1.0     NaN     6.0       1         1        53         3
# 2     83734     1.0     NaN     NaN       1         1        78         3
# 3     83735     2.0     1.0     1.0       2         2        56         3
# 4     83736     2.0     1.0     1.0       2         2        42         4
# ...     ...     ...     ...     ...     ...       ...       ...       ...
# 5730  93695     2.0     2.0     NaN       1         2        76         3
# 5731  93696     2.0     2.0     NaN       2         1        26         3
# 5732  93697     1.0     NaN     1.0       1         2        80         3
# 5733  93700     NaN     NaN     NaN       1         1        35         3
# 5734  93702     1.0     NaN     2.0       2         2        24         3
#
#       DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0          1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1          2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2          1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3          1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4          1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
# ...        ...       ...  ...     ...     ...    ...    ...     ...     ...
# 5730       1.0       3.0  ...   112.0    46.0   59.1  165.8    21.5    38.2
# 5731       1.0       5.0  ...   116.0    76.0  112.1  182.2    33.8    43.4
# 5732       1.0       4.0  ...   146.0    58.0   71.7  152.2    31.0    31.3
# 5733       2.0       1.0  ...   106.0    66.0   78.2  173.3    26.0    40.3
# 5734       1.0       5.0  ...   114.0    68.0   58.3  165.0    21.4    38.2
#
#       BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0        43.6     35.9     101.1     2.0
# 1        40.0     33.2     107.9     NaN
# 2        37.0     31.0     116.5     2.0
# 3        37.7     38.3     110.1     2.0
# 4        36.0     27.2      80.4     2.0
# ...       ...      ...       ...     ...
# 5730     37.0     29.5      95.0     2.0
# 5731     41.8     42.3     110.2     2.0
# 5732     37.5     28.8       NaN     2.0
# 5733     37.5     30.6      98.9     2.0
# 5734     33.5     26.2      72.5     2.0
#
# [5735 rows x 28 columns]

# %% [markdown]
# Uji apakah rata2 BMI dari Laki-Laki lebih tinggi dari pada rata2 BMI Perempuan
#
# h0 = rata2 BMI Laki-Laki tidak lebih tinggi signifikan dari perempuan
#
# h1 = rata2 BMI Laki2 lebih tinggi signifikan dari perempuan
#
# h0 : meanL <= meanP
#
# h1: meanL > meanP
#
# RIAGENDR female = 2 Male=1

# %%
females = df[df.RIAGENDR==2]
males = df[df.RIAGENDR==1]

# %%
# jumlah data, mean, stdeviasi
n_females = len(females)
mean_females = females['BMXBMI'].mean()
std_females = females['BMXBMI'].std()
print(n_females,mean_females,std_females)
# Out:
# 2976 29.93994565217392 7.753318809545674

# %%
# jumlah data, mean, stdeviasi
n_males = len(males)
mean_males = males['BMXBMI'].mean()
std_males = males['BMXBMI'].std()
print(n_males,mean_males,std_males)
# Out:
# 2759 28.778072111846942 6.2525676168014614

# %% [markdown]
# h0 : meanL <= meanP
#
# h1: meanL > meanP

# %%
import statsmodels.api as sm

# %%
#karena confidence level 95% maka alpha=0.05
alpha = 0.05

# %%
bmi_hypo = sm.stats.ztest(males['BMXBMI'].dropna(),females['BMXBMI'].dropna(),alternative='larger')
bmi_hypo
# Out:
# (-6.1755933531383205, 0.9999999996704227)

# %%
if bmi_hypo[1]>alpha:
    print('Accept Null Hypothesis (h0) Mean of Males BMI is not Larger than Females')
else:
    print('Reject Null Hypothesis (h0)  Mean of Males BMI is Larger than Females')
# Out:
# Accept Null Hypothesis (h0) Mean of Males BMI is not Larger than Females

# %% [markdown]
# **Data sama hipotesis berbeda**

# %% [markdown]
# Uji apakah mean BMI Laki Laki tidak sama dengan mean BMI Perempuan
#
# h0 : meanL = meanP
#
# h1: meanL != meanP

# %%
bmi_hypo_2s = sm.stats.ztest(males['BMXBMI'].dropna(),females['BMXBMI'].dropna(),alternative='two-sided')
bmi_hypo_2s
# Out:
# (-6.1755933531383205, 6.591544431126401e-10)

# %% [markdown]
# **Hypothesis Testing Population Proportion**

# %%
img = Image.open('/content/drive/MyDrive/Colab Notebooks/sesi_10 Inferential Statistics/17.png')
img.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=719x270 at 0x7FD6825FC490>

# %%
n = 1018
pro_null = 0.52
pro_alt = 0.56

# %%
pro_hypo = sm.stats.proportions_ztest(n*pro_alt,n,pro_null,alternative='larger')
pro_hypo
# Out:
# (2.571067795759113, 0.005069273865860533)

# %%
if pro_hypo[1]>alpha:
    print('Accept Null Hypothesis (h0)')
else:
    print('Reject Null Hypothesis (h0)')
# Out:
# Reject Null Hypothesis (h0)
